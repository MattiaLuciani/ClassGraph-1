# %%
import sys
import os
import subprocess
import csv
import operator
import time
import argparse
import re
import logging
from igraph import * 

sgafile = '/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/data/ids.txt'
count1 = 0 
count2 = 0 
count3 = 0 
count4 = 0 
count5 = 0 
count6 = 0 
count7 = 0 
count8 = 0 

with open(sgafile, 'r') as infile1:
    for line in infile1:
        if line.startswith("AP011170.1_Acetobacter_pasteurianus_IFO_3283-12_DNA"):
            count1 = count1 + 1
    
        if line.startswith("NC_011658.1_Bacillus_cereus_AH187"):
            count2 = count2 + 1

        if line.startswith("CP002807.1_Chlamydia_psittaci_08DC60_chromosome"):
            count3 = count3 + 1
            
        if line.startswith("NC_011415.1_Escherichia_coli_SE11,_complete_sequence"):
            count4 = count4 + 1
            
        if line.startswith("FQ312002.1_Haemophilus_parainfluenzae_T3T1_complete_genome"):
            count5 = count5 + 1
            
        if line.startswith("CP002618.1_Lactobacillus_paracasei_strain_BD-II"):
            count6 = count6 + 1
            
        if line.startswith("NC_013929.1_Streptomyces_scabiei_87.22_complete_genome"):
            count7 = count7 + 1

        if line.startswith("NC_012883.1_Thermococcus_sibiricus_MM_739"):
            count8 = count8 + 1

    print('1', count1)
    print('2', count2)   
    print('3', count3)  
    print('4', count4)
    print('5', count5)
    print('6', count6)
    print('7', count7)
    print('8', count8)
# Out:
# 1 8538
# 2 30977
# 3 11024
# 4 71835
# 5 85882
# 6 72193
# 7 119330
# 8 32554

# %%
output_path = '/Users/mattialuciani/Desktop/Senza nome'
output_file = output_path + 'primo'

with open(output_file, mode='w') as out_file:

    for v in range(8538):
        c = str(v)

        out_file.write("read_" + c + "\t" + "438" + "\n")

    for v in range(30977):
        a = v + 8538
        b = str(a)
        out_file.write("read_" + b + "\t" + "86661" + "\n")

    for v in range(11024):
        a = v + 39515
        b = str(a)
        out_file.write("read_" + b + "\t" + "83554" + "\n")

    for v in range(71835):
        a = v + 50539
        b = str(a)
        out_file.write("read_" + b + "\t" + "543" + "\n")

    for v in range(85882):
        a = v + 122374
        b = str(a)
        out_file.write("read_" + b + "\t" + "862965" + "\n")

    for v in range(72193):
        a = v + 208256
        b = str(a)
        out_file.write("read_" + b + "\t" + "655183" + "\n")

    for v in range(119330):
        a = v + 280449
        b = str(a)
        out_file.write("read_" + b + "\t" + "680198" + "\n")

    for v in range(32554):
        a = v + 399779
        b = str(a)
        out_file.write("read_" + b + "\t" + "604354" + "\n")

# %%
#nuovo file truth

output_path = '/Users/mattialuciani/Desktop'
output_file = output_path + 'primo'

with open('/Users/mattialuciani/Desktop/truth_Sim8', mode='w') as out_file:

    for v in range(8538):
        c = str(v)

        out_file.write("read_" + c + "\t" + "438" + "\n")

    for v in range(30977):
        a = v + 8538
        b = str(a)
        out_file.write("read_" + b + "\t" + "1396" + "\n")

    for v in range(11024):
        a = v + 39515
        b = str(a)
        out_file.write("read_" + b + "\t" + "83554" + "\n")

    for v in range(71835):
        a = v + 50539
        b = str(a)
        out_file.write("read_" + b + "\t" + "562" + "\n")

    for v in range(85882):
        a = v + 122374
        b = str(a)
        out_file.write("read_" + b + "\t" + "729" + "\n")

    for v in range(72193):
        a = v + 208256
        b = str(a)
        out_file.write("read_" + b + "\t" + "655183" + "\n")

    for v in range(119330):
        a = v + 280449
        b = str(a)
        out_file.write("read_" + b + "\t" + "1930" + "\n")

    for v in range(32554):
        a = v + 399779
        b = str(a)
        out_file.write("read_" + b + "\t" + "172049" + "\n")

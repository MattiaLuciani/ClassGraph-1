# %%
#file binning a livello specie (7)


krakenfile = '/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/marine/kraken_out_marine_DBKraken2.res'
krakenreport = '/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/report_kraken/k2_report_marine_DBKraken2.txt'
lista = []


with open(krakenreport, 'r') as infile2:
    for line in infile2:
        words = line.split()
        if words[3] != 'S':
            if words[3] != 'S1':
                if words[3] != 'S2':
                    if words[3] != 'S3':
                        lista.append(words[4]) 
        
#(U)nclassified, (R)oot, (D)omain, (K)ingdom, (P)hylum, (C)lass, (O)rder, (F)amily, (G)enus, or (S)pecies

with open(krakenfile, 'r') as infile1:
    for line in infile1:
        words = line.split()
        read = words[0]
        label = words[1]
        if label in lista:
            label = '0'  
        with open('/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/marine/kraken_out_marine_DBKraken2-spec.res', mode='a') as out_file:
            out_file.write(read + '\t' + label  + '\n')

# %%
krakenfile = '/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/marine/kraken_out_marine_DBKraken2-spec-0.res'
lista = []
with open(krakenfile, 'r') as infile1:
    for line in infile1:
        words = line.split()
        read = words[0]
        label = words[1]

        #Acetobacter pasteurianus
        if label == '472759':
            label = '133539'  
        if label == '323261':
            label = '1229'  
        if label == '765911':
            label = '73141'  
        if label == '1260251':
            label = '1335746'  
        if label == '1384040':
            label = '190893'  
        if label == '1191300':
            label = '246167'  
        if label == '1051646':
            label = '29498'  
        if label == '316275':
            label = '40269'  
        if label == '388396':
            label = '668'  
        if label == '658445':
            label = '1295392'  
        if label == '298386':
            label = '74109'  
        if label == '1300254':
            label = '314275'  
        if label == '1300256':
            label = '314275'  
        if label == '1774373':
            label = '314275'  
        if label == '1004787':
            label = '28108'  
        if label == '529120':
            label = '28108'  
        if label == '351348':
            label = '2743'  
        if label == '1085623':
            label = '300231'  
        if label == '1129794':
            label = '326544'  
        if label == '458817':
            label = '271098'  
        if label == '407976':
            label = '62322'  
        if label == '225849':
            label = '404011'  
        if label == '323850':
            label = '359303'  
        if label == '167879':
            label = '28229'  
        if label == '342610':
            label = '288'  
        if label == '1315283':
            label = '166935'  
        if label == '491952':
            label = '936476'  
        if label == '717774':
            label = '119864'  
        if label == '1208320':
            label = '187493'  
        if label == '1298593':
            label = '187493'  
        if label == '698738':
            label = '188908'  
        if label == '523791':
            label = '261964'  
        if label == '349521':
            label = '158327'  
        if label == '391936':
            label = '1306787'  
        if label == '743713':
            label = '294'  
        if label == '1221522':
            label = '294'  
        if label == '1123016':
            label = '74829'  
        if label == '1198232':
            label = '1329899'  
        if label == '317025':
            label = '39765'  
        if label == '29491':
            label = '645'  
        if label == '377629':
            label = '2426'  
        if label == '1193729':
            label = '1263979'  
        if label == '1401328':
            label = '1263979'  
        if label == '1110502':
            label = '171437'  
        if label == '391626':
            label = '1217908'  
        if label == '999552':
            label = '133924'  
        if label == '666509':
            label = '1284658'  
        if label == '1294273':
            label = '159346'  
        if label == '228405':
            label = '81032'  
        if label == '582402':
            label = '2724'  
        if label == '394221':
            label = '74318'  
        if label == '1029756':
            label = '1427356'  
        if label == '314225':
            label = '39960'  
        if label == '156889':
            label = '1124597'  
        if label == '314260':
            label = '208216'  
        if label == '314225':
            label = '39960'  
        if label == '156889':
            label = '1124597'  
        if label == '314260':
            label = '208216'  
        if label == '326298':
            label = '39766'  
        if label == '651182':
            label = '28223'  
        if label == '885957':
            label = '83564'  
        if label == '2752305':
            label = '83564'  
        if label == '641491':
            label = '876'  
        if label == '526222':
            label = '880'  
        if label == '1121451':
            label = '191026'  
        if label == '883':
            label = '881'  
        if label == '690850':
            label = '873'  
        if label == '1144275':
            label = '184914'  
        if label == '448385':
            label = '56'  
        if label == '1254432':
            label = '56'  
        if label == '760142':
            label = '84405'  
        if label == '338969':
            label = '192843'  
        if label == '543728':
            label = '34073'  
        if label == '595537':
            label = '34073'  
        if label == '1246301':
            label = '34073'  
        if label == '365046':
            label = '94132'  
        if label == '1042878':
            label = '106590'  
        if label == '381666':
            label = '106590'
        if label == '1417228':
            label = '261302'  
        if label == '398527':
            label = '261302'  
        if label == '1069642':
            label = '959'  
        if label == '765869':
            label = '959'  
        if label == '862908':
            label = '97084'  
        if label == '67263':
            label = '1911'  
        if label == '455632':
            label = '1911'  
        if label == '1172567':
            label = '1908'  
        if label == '1079985':
            label = '1969'  
        if label == '369723':
            label = '168695'
        if label == '391037':
            label = '168697'  
        if label == '263358':
            label = '1003110'  
        if label == '1289591':
            label = '1833'  
        if label == '234621':
            label = '1833'  
        if label == '1136179':
            label = '1833'  
        if label == '632772':
            label = '37919'  
        if label == '1443893':
            label = '1828'  
        if label == '1051973':
            label = '1828'  
        if label == '1443894':
            label = '1828'  
        if label == '1133849':
            label = '37326'
        if label == '710421':
            label = '1800'  
        if label == '521096':
            label = '2061'  
        if label == '478801':
            label = '1276'  
        if label == '1313172':
            label = '467094'  
        if label == '1367477':
            label = '324767'  
        if label == '526986':
            label = '1396'  
        if label == '221109':
            label = '182710'  
        if label == '1333534':
            label = '44251'  
        if label == '1359':
            label = '1358'  
        if label == '1360':
            label = '1358'
        if label == '1415774':
            label = '1491'  
        if label == '935198':
            label = '1491'  
        if label == '693746':
            label = '351091'  
        if label == '74547':
            label = '1219'  
        if label == '167542':
            label = '1219'  
        if label == '59919':
            label = '1219'  
        if label == '167555':
            label = '1219'  
        if label == '167546':
            label = '1219'  
        if label == '1188229':
            label = '1188228'  
        if label == '869210':
            label = '186192'
        if label == '1348584':
            label = '76594'  
        if label == '643867':
            label = '1006'  
        if label == '518766':
            label = '29549'
        if label == '761659':
            label = '146919'  
        if label == '517418':
            label = '100716'  
        if label == '984262':
            label = '1008'  
        if label == '290318':
            label = '1094'  
        if label == '572544':
            label = '167642'  
        if label == '76859':
            label = '851'  
        if label == '868864':
            label = '64160'  
        if label == '1343739':
            label = '971279'  
        if label == '272844':
            label = '29292'  
        if label == '1434120':
            label = '38027'
        if label == '1434118':
            label = '38027'  
        if label == '1434107':
            label = '2208'  
        if label == '368407':
            label = '2198'
        if label == '1033806':
            label = '430914'  
        if label == '523841':
            label = '2252'  
        if label == '768065':
            label = '293091'  
        if label == '1344584':
            label = '2234'  
        if label == '426368':
            label = '39152'  
        if label == '439481':
            label = '379547'  
        if label == '415426':
            label = '54248'  
        if label == '940295':
            label = '54259'  
        if label == '399550':
            label = '2280'  

        with open('/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/marine/kraken_out_marine_DBKraken2-spec.res', mode='a') as out_file:
            out_file.write(read + '\t' + label  + '\n')

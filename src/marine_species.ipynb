# %%
asqg_file = '/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/report_kraken/k2_report_SRR7585901_DBKraken2.txt'
c = 0
with open(asqg_file, 'r') as file:
    for line in file:
        words = line.split()
        words1 = words[0].split('.')
        if int(words[2]) > 100:
            #if float(words1[0]) > 1:
        #        print(line)
        #if int(words[2]) > 1000:
        #if words[2] == 'S' or words[2] == 'S1':
                print(line)
# Out:
#  11.84	90360	90360	U	0	unclassified
#
#  88.16	672975	480	R	1	root
#
#  87.44	667466	1111	R1	131567	  cellular organisms
#
#  83.97	640985	831	D	2	    Bacteria
#
#  82.37	628793	225	D1	1783272	      Terrabacteria group
#
#  82.14	627014	111	P	1239	        Firmicutes
#
#  82.03	626198	235	C	91061	          Bacilli
#
#  81.84	624751	619	O	186826	            Lactobacillales
#
#  51.56	393539	741	F	33958	              Lactobacillaceae
#
#  51.24	391161	28175	G	1578	                Lactobacillus
#
#  34.77	265436	195361	S	1587	                  Lactobacillus helveticus
#
#   4.34	33159	33159	S1	880633	                    Lactobacillus helveticus R0052
#
#   1.68	12839	12839	S1	767456	                    Lactobacillus helveticus H9
#
#   1.29	9815	9815	S1	326425	                    Lactobacillus helveticus CNRZ32
#
#   0.97	7410	7410	S1	405566	                    Lactobacillus helveticus DPC 4571
#
#   0.90	6852	6852	S1	767462	                    Lactobacillus helveticus H10
#
# ...

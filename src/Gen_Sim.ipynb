# %%
reads_file1 = '/Users/mattialuciani/Desktop/Sim_20/reads/Amycolatopsis_mediterranei.fastq'
reads_file2 = '/Users/mattialuciani/Desktop/Sim_20/reads/Arthrobacter_arilaitensis.fastq'
reads_file3 = '/Users/mattialuciani/Desktop/Sim_20/reads/Azorhizobium_caulinodans.fastq'
reads_file4 = '/Users/mattialuciani/Desktop/Sim_20/reads/Bdellovibrio_bacteriovorus.fastq'
reads_file5 = '/Users/mattialuciani/Desktop/Sim_20/reads/Bifidobacterium_animalis.fastq'
reads_file6 = '/Users/mattialuciani/Desktop/Sim_20/reads/Brachyspira_intermedia.fastq'
reads_file7 = '/Users/mattialuciani/Desktop/Sim_20/reads/Candidatus_Pelagibacter_ubique.fastq'
reads_file8 = '/Users/mattialuciani/Desktop/Sim_20/reads/Clostridium_thermocellum.fastq'
reads_file9 = '/Users/mattialuciani/Desktop/Sim_20/reads/Corynebacterium_ulcerans.fastq'
reads_file10 = '/Users/mattialuciani/Desktop/Sim_20/reads/Erysipelothrix_rhusiopathiae.fastq'
reads_file11 = '/Users/mattialuciani/Desktop/Sim_20/reads/Francisella_novicida.fastq'
reads_file12 = '/Users/mattialuciani/Desktop/Sim_20/reads/Halobacterium.fastq'
reads_file13 = '/Users/mattialuciani/Desktop/Sim_20/reads/Mycobacterium_bovis.fastq'
reads_file14 = '/Users/mattialuciani/Desktop/Sim_20/reads/Nitrosococcus_watsonii.fastq'
reads_file15 = '/Users/mattialuciani/Desktop/Sim_20/reads/Paenibacillus_mucilaginosus.fastq'
reads_file16 = '/Users/mattialuciani/Desktop/Sim_20/reads/Photobacterium_profundum.fastq'
reads_file17 = '/Users/mattialuciani/Desktop/Sim_20/reads/Rickettsia_prowazekii.fastq'
reads_file18 = '/Users/mattialuciani/Desktop/Sim_20/reads/Symbiobacterium_thermophilum.fastq'
reads_file19 = '/Users/mattialuciani/Desktop/Sim_20/reads/Thermococcus_sibiricus.fastq'
reads_file20 = '/Users/mattialuciani/Desktop/Sim_20/reads/Xanthobacter_autotrophicus.fastq'

long = [31168, 31017, 16349, 9675, 7300, 8057, 10617, 14510, 10056, 8508, 34874, 21617, 39740, 39029, 94013, 64041, 13507, 14863, 47207, 91585]

output_file = '/Users/mattialuciani/Desktop/Sim_20/Sim_20.fasta'

c = 0
with open(output_file, mode='w') as out_file:

    with open(reads_file1, 'r') as file:
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")


    with open(reads_file2, 'r') as file:
        c = 31168
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")
              

    with open(reads_file3, 'r') as file:
        c = 62185
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")
        
    with open(reads_file4, 'r') as file:
        c = 78534
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file5, 'r') as file:
        c = 88209
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")
                
    with open(reads_file6, 'r') as file:
        c = 95509
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file7, 'r') as file:
        c = 103566
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file8, 'r') as file:
        c = 114183
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file9, 'r') as file:
        c = 128693
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file10, 'r') as file:
        c = 138749
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file11, 'r') as file:
        c = 147257
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file12, 'r') as file:
        c = 182131
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file13, 'r') as file:
        c = 203748
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file14, 'r') as file:
        c = 242488
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file15, 'r') as file:
        c = 282517
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file16, 'r') as file:
        c = 376530
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file17, 'r') as file:
        c = 440571
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file18, 'r') as file:
        c = 454078
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file19, 'r') as file:
        c = 562657
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

    with open(reads_file20, 'r') as file:
        c = 
        for line in file:
                if line.startswith("G") or line.startswith("A") or line.startswith("C") or line.startswith("T"):
                    c = c + 1
                    v = str(c)
                    out_file.write(">read_" + v + "\n" + line + "\n")

# %%
#file binning a livello specie (7)


krakenfile = '/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/Sim_50/kraken2_Sim_50_DBKraken2.res'
krakenreport = '/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/report_kraken/k2_report_Sim_50_DBKraken2.txt'
lista = []


with open(krakenreport, 'r') as infile2:
    for line in infile2:
        words = line.split()
        if words[3] != 'S':
            if words[3] != 'S1':
                if words[3] != 'S2':
                    if words[3] != 'S3':
                        lista.append(words[4]) 
        
#(U)nclassified, (R)oot, (D)omain, (K)ingdom, (P)hylum, (C)lass, (O)rder, (F)amily, (G)enus, or (S)pecies

with open(krakenfile, 'r') as infile1:
    for line in infile1:
        words = line.split()
        read = words[0]
        label = words[1]
        if label in lista:
            label = '0'  
        #with open('/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/Sim_50/kraken_out_Sim50_DBKraken2-spec.res', mode='a') as out_file:
            #out_file.write(read + '\t' + label  + '\n')

# %%
krakenfile = '/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/Sim_50/kraken2_Sim_50_DBKraken2.res'
lista = []
with open(krakenfile, 'r') as infile1:
    for line in infile1:
        words = line.split()
        read = words[0]
        label = words[1]

        #Acetobacter pasteurianus
        if label == '292459':
            label = '2734'  
        if label == '212717':
            label = '1513'  
        if label == '1231072':
            label = '1513'   
        if label == '203119':
            label = '1515'  
        if label == '1036673':
            label = '61624'  
        if label == '1116391':
            label = '61624'  
        if label == '997761':
            label = '61624'  
        if label == '222523':
            label = '1396'   
        if label == '324831':
            label = '1596'  
        if label == '1380360':
            label = '1596'  
        if label == '334390':
            label = '1613'  
        if label == '680198':
            label = '1930'  
        if label == '861360':
            label = '256701'   
        if label == '1205674':
            label = '78331'  
        if label == '1205677':
            label = '78331'  
        if label == '945711':
            label = '65058'  
        if label == '367928':
            label = '1680'  
        if label == '243230':
            label = '1299'  
        if label == '302409':
            label = '779'  
        if label == '557760':
            label = '1063'  
        if label == '992186':
            label = '1063'  
        if label == '78245':
            label = '280'  
        if label == '438753':
            label = '7'  
        if label == '335992':
            label = '198252'  
        if label == '228400':
            label = '731'  
        if label == '862965':
            label = '729'  
        if label == '105559':
            label = '473531'  
        if label == '264':
            label = '263'  
        if label == '1450527':
            label = '263'  
        if label == '984129':
            label = '263'  
        if label == '298386':
            label = '74109'  
        if label == '264462':
            label = '959'  
        if label == '1069642':
            label = '959'  
        if label == '76857':
            label = '851'  
        if label == '1045858':
            label = '84377'  
        if label == '604354':
            label = '172049'  
        if label == '1434107':
            label = '2208'  
        if label == '420247':
            label = '2173'  
        if label == '1163730':
            label = '683846'  
         
        with open('/Users/mattialuciani/Desktop/università_magistrale/bioinformatics/tesi/Sim_50/kraken_out_Sim50_DBKraken2_species2.res', mode='a') as out_file:
            out_file.write(read + '\t' + label  + '\n')
